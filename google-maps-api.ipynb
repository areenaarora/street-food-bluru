# %% [markdown]
# #### All the necessary imports

# %%
import requests
import pandas as pd
import time
import json
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Requesting API data from Google maps
#
# #### For the parameters given, I inserted the latitude and longitude you get for Bangalore, a southern Indian city, from googling for it. For the radius, I chose 2000 (it's in meters, so that would be 20 km — a totally arbitrary choice!)

# %%
url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
API_KEY = os.getenv("API_KEY")
payload={
    "location": "12.9716, 77.5946", #split the city up
    "radius": "20000",
    "type": "restaurant",
    "key": API_KEY
}

page_1_response = requests.get(url, params=payload)
# print(response.text)

page_2_token = page_1_response.json()['next_page_token']
# print(page_2_token)

payload_two={
    "location": "12.9716, 77.5946",
    "radius": "20000",
    "type": "restaurant",
    "key": API_KEY,
    "pagetoken": page_2_token
}
time.sleep(5)
page_2_response = requests.get(url, params=payload_two)
# print(page_2_response.text)

page_3_token = page_2_response.json()['next_page_token']
# print(page_2_token)

payload_three={
    "location": "12.9716, 77.5946",
    "radius": "20000",
    "type": "restaurant", #try food stall here!
    "key": API_KEY,
    "pagetoken": page_3_token
}
time.sleep(5)
page_3_response = requests.get(url, params=payload_three)
# print(page_3_response.text)
print(page_3_response.json()["status"])
# Out:
# OK

# %% [markdown]
# #### Note that Google Maps API doesn't give out more than 20 results per query and each search can only yield a maximum of 60 results. So here I've used the next page to token to scrape all 60 results possible and then combined them into a dataframe for visualization.

# %%
master_list = []

master_list.extend(page_1_response.json()['results'])
master_list.extend(page_2_response.json()['results'])
master_list.extend(page_3_response.json()['results'])

# %%
# print(json.dumps(master_list))

# %%
df = pd.DataFrame(master_list)

# %%
# df.columns

# %%
del df['icon']
del df['icon_background_color']
del df['icon_mask_base_uri']
del df['opening_hours']
del df['photos']
del df['place_id']
del df['plus_code']
del df['reference']
del df['permanently_closed']
del df['scope']

# %%
df
# Out:
#        business_status                                           geometry  \
# 0          OPERATIONAL  {'location': {'lat': 12.9657028, 'lng': 77.598...
# 1          OPERATIONAL  {'location': {'lat': 12.9716313, 'lng': 77.595...
# 2          OPERATIONAL  {'location': {'lat': 12.9894732, 'lng': 77.594...
# 3          OPERATIONAL  {'location': {'lat': 12.966784, 'lng': 77.6062...
# 4          OPERATIONAL  {'location': {'lat': 12.9717869, 'lng': 77.596...
# 5          OPERATIONAL  {'location': {'lat': 12.9718487, 'lng': 77.598...
# 6   CLOSED_TEMPORARILY  {'location': {'lat': 12.9715987, 'lng': 77.594...
# 7          OPERATIONAL  {'location': {'lat': 12.9708863, 'lng': 77.597...
# 8          OPERATIONAL  {'location': {'lat': 12.9754414, 'lng': 77.602...
# 9          OPERATIONAL  {'location': {'lat': 12.97326, 'lng': 77.60345...
# 10         OPERATIONAL  {'location': {'lat': 12.9761788, 'lng': 77.601...
# 11         OPERATIONAL  {'location': {'lat': 12.9797611, 'lng': 77.602...
# 12         OPERATIONAL  {'location': {'lat': 12.9758366, 'lng': 77.601...
# 13         OPERATIONAL  {'location': {'lat': 12.969842, 'lng': 77.6068...
# 14         OPERATIONAL  {'location': {'lat': 12.982582, 'lng': 77.5945...
# 15         OPERATIONAL  {'location': {'lat': 12.9738194, 'lng': 77.609...
# 16         OPERATIONAL  {'location': {'lat': 12.966775, 'lng': 77.6083...
# 17         OPERATIONAL  {'location': {'lat': 12.973678, 'lng': 77.6073...
# 18         OPERATIONAL  {'location': {'lat': 12.9825481, 'lng': 77.594...
# 19         OPERATIONAL  {'location': {'lat': 12.9717269, 'lng': 77.596...
# 20  CLOSED_TEMPORARILY  {'location': {'lat': 12.9712973, 'lng': 77.600...
# 21         OPERATIONAL  {'location': {'lat': 12.9744745, 'lng': 77.609...
# 22         OPERATIONAL  {'location': {'lat': 12.9728961, 'lng': 77.609...
# 23         OPERATIONAL  {'location': {'lat': 12.9624628, 'lng': 77.599...
# 24         OPERATIONAL  {'location': {'lat': 12.9733569, 'lng': 77.609...
# 25         OPERATIONAL  {'location': {'lat': 12.9751838, 'lng': 77.603...
# 26         OPERATIONAL  {'location': {'lat': 12.9752373, 'lng': 77.604...
# 27         OPERATIONAL  {'location': {'lat': 12.9709896, 'lng': 77.606...
# 28         OPERATIONAL  {'location': {'lat': 12.9729231, 'lng': 77.608...
# 29         OPERATIONAL  {'location': {'lat': 12.975206, 'lng': 77.6055...
# 30         OPERATIONAL  {'location': {'lat': 12.9717197, 'lng': 77.594...
# 31         OPERATIONAL  {'location': {'lat': 12.9628079, 'lng': 77.595...
# 32         OPERATIONAL  {'location': {'lat': 12.9623716, 'lng': 77.593...
# 33         OPERATIONAL  {'location': {'lat': 12.9578859, 'lng': 77.593...
# 34         OPERATIONAL  {'location': {'lat': 12.9832549, 'lng': 77.592...
# 35         OPERATIONAL  {'location': {'lat': 12.9692097, 'lng': 77.606...
# 36  CLOSED_TEMPORARILY  {'location': {'lat': 12.9697166, 'lng': 77.610...
# 37         OPERATIONAL  {'location': {'lat': 12.9863813, 'lng': 77.595...
# 38         OPERATIONAL  {'location': {'lat': 12.9717013, 'lng': 77.596...
# 39         OPERATIONAL  {'location': {'lat': 12.9723803, 'lng': 77.608...
# 40         OPERATIONAL  {'location': {'lat': 12.9757392, 'lng': 77.602...
# 41         OPERATIONAL  {'location': {'lat': 12.9674414, 'lng': 77.608...
# 42         OPERATIONAL  {'location': {'lat': 12.9657887, 'lng': 77.601...
# 43         OPERATIONAL  {'location': {'lat': 12.9703756, 'lng': 77.611...
# 44         OPERATIONAL  {'location': {'lat': 12.9654972, 'lng': 77.589...
# 45         OPERATIONAL  {'location': {'lat': 12.9732873, 'lng': 77.607...
# 46         OPERATIONAL  {'location': {'lat': 12.9714486, 'lng': 77.596...
# 47         OPERATIONAL  {'location': {'lat': 12.9707303, 'lng': 77.597...
# 48         OPERATIONAL  {'location': {'lat': 12.9758445, 'lng': 77.601...
# 49         OPERATIONAL  {'location': {'lat': 12.9715987, 'lng': 77.594...
# 50         OPERATIONAL  {'location': {'lat': 12.9751637, 'lng': 77.603...
# 51         OPERATIONAL  {'location': {'lat': 12.9820816, 'lng': 77.603...
# 52         OPERATIONAL  {'location': {'lat': 12.98705, 'lng': 77.59471...
# 53         OPERATIONAL  {'location': {'lat': 12.9645418, 'lng': 77.606...
# 54         OPERATIONAL  {'location': {'lat': 12.9710906, 'lng': 77.605...
# 55         OPERATIONAL  {'location': {'lat': 12.9755069, 'lng': 77.603...
# 56         OPERATIONAL  {'location': {'lat': 12.9890957, 'lng': 77.593...
# 57         OPERATIONAL  {'location': {'lat': 12.9676354, 'lng': 77.599...
# 58         OPERATIONAL  {'location': {'lat': 12.9714255, 'lng': 77.597...
# 59         OPERATIONAL  {'location': {'lat': 12.972071, 'lng': 77.5966...
#
#                                                  name  rating  \
# 0                               The Chancery Pavilion     4.1
# 1                  Oakwood Premier Prestige Bangalore     4.6
# 2                            Fortune Select JP Cosmos     4.1
# 3                                    Tom's Restaurant     4.3
# 4                                           Cafe Noir     4.2
# 5                                  Sunny's Restaurant     4.1
# 6                                  Mahesh Enterprises     NaN
# 7                                      The Biere Club     4.3
# 8                   Empire Restaurant - Church Street     3.9
# 9                                      The Only Place     4.2
# 10                                     Hard Rock Cafe     4.4
# 11                      Hotel empire - Central Street     4.2
# 12                               K.C.Das Private Ltd.     4.1
# 13                       The Ocea International Hotel     4.0
# 14                                       Hotel Paraag     3.8
# 15                               Chung Wah Restaurant     4.0
# 16                                        Olive Beach     4.3
# 17                                    Pecos - Classic     4.3
# 18                                  The Capitol Hotel     4.0
# 19                                             Subway     4.0
# 20                                     Northern Route     4.3
# 21                                  Canopy Restaurant     3.7
# 22                                      Meghana Foods     4.3
# 23                                          Pizza Hut     3.9
# 24                                        Green Onion     4.3
# 25                                           Bheema's     4.1
# 26                                      Coconut Grove     3.9
# 27                                  Stars 'N' Stripes     3.3
# 28                                      Down Town Pub     3.9
# 29                                     The 13th Floor     4.3
# 30                                    Cafe Coffee Day     4.3
# 31                                  Shyvan Restaurant     3.8
# 32                          Sandarshini Sweet Shoppe.     4.0
# 33                                             Foodys     3.9
# 34                                        Upper House     NaN
# 35                                              PlanB     4.1
# 36                                    Café Coffee Day     3.5
# 37                                Banjara Melting Pot     4.0
# 38                         Rasovara The Royal Kitchen     4.1
# 39                                          Karavalli     4.5
# 40                                     Domino's Pizza     4.1
# 41                                              Asean     4.0
# 42                      Beijing Bites - Richmond Town     3.9
# 43                              Arbor Brewing Company     4.4
# 44                                Hotel V.T. Paradise     3.9
# 45                                         McDonald's     4.1
# 46                                              Shiro     4.3
# 47                               Tattv Gourmet Kebabs     3.3
# 48                                Koshy's Parade Café     4.1
# 49                             होटल श्री कृष्णा उपहार     4.1
# 50                                       Oh! Calcutta     4.2
# 51                                Imperial Restaurant     3.7
# 52                          infinitea Cunningham road     4.4
# 53                                       Hotel Fanoos     3.9
# 54                                     Hotel Imperial     4.0
# 55                                         Kaati Zone     3.5
# 56                             Chung's Chinese Corner     3.9
# 57  Sarathi's Spicy Tadka Multi Cuisine Family Res...     3.6
# 58                                             CLUB 9     4.0
# 59                                Soul City ಸೋಲ್ ಸಿಟಿ     4.1
#
#                                                 types  user_ratings_total  \
# 0   [lodging, restaurant, food, point_of_interest,...             13803.0
# 1   [night_club, spa, lodging, bar, restaurant, fo...              2095.0
# 2   [lodging, restaurant, food, point_of_interest,...              3345.0
# 3   [restaurant, food, point_of_interest, establis...              1446.0
# 4   [cafe, bar, restaurant, food, point_of_interes...              2338.0
# 5   [restaurant, food, point_of_interest, establis...              2109.0
# 6   [restaurant, food, point_of_interest, establis...                 NaN
# 7   [bar, restaurant, food, point_of_interest, est...              8838.0
# 8   [restaurant, food, point_of_interest, establis...             14736.0
# 9   [cafe, restaurant, food, point_of_interest, es...              5559.0
# 10  [restaurant, food, point_of_interest, establis...             11692.0
# 11  [restaurant, food, point_of_interest, establis...             12880.0
# 12  [restaurant, food, point_of_interest, establis...              1720.0
# 13  [lodging, restaurant, food, point_of_interest,...              2621.0
# 14  [lodging, restaurant, food, point_of_interest,...              1692.0
# 15  [restaurant, food, point_of_interest, establis...              1060.0
# 16  [bar, restaurant, food, point_of_interest, est...              3340.0
# 17  [bar, restaurant, food, point_of_interest, est...              1636.0
# 18  [lodging, bar, restaurant, food, point_of_inte...              5682.0
# 19  [restaurant, food, point_of_interest, establis...               219.0
# 20  [restaurant, food, point_of_interest, establis...               716.0
# 21  [restaurant, food, point_of_interest, establis...               566.0
# 22  [restaurant, food, point_of_interest, establis...             15275.0
# 23  [meal_delivery, restaurant, food, point_of_int...              1195.0
# 24  [restaurant, food, point_of_interest, establis...              3821.0
# 25  [restaurant, food, point_of_interest, establis...              4983.0
# 26  [restaurant, food, point_of_interest, establis...              2225.0
# 27  [restaurant, food, point_of_interest, establis...                69.0
# 28  [bar, restaurant, food, point_of_interest, est...               573.0
# 29  [bar, restaurant, food, point_of_interest, est...              6396.0
# 30  [cafe, restaurant, food, point_of_interest, st...              3729.0
# 31  [restaurant, food, point_of_interest, establis...               334.0
# 32  [restaurant, food, point_of_interest, store, e...               155.0
# 33  [restaurant, food, point_of_interest, store, e...              3768.0
# 34  [restaurant, food, point_of_interest, establis...                 NaN
# 35  [bar, restaurant, food, point_of_interest, est...              4155.0
# 36  [cafe, restaurant, food, point_of_interest, st...               104.0
# 37  [restaurant, food, point_of_interest, establis...              1348.0
# 38  [restaurant, food, point_of_interest, establis...              1708.0
# 39  [restaurant, food, point_of_interest, establis...              2822.0
# 40  [meal_delivery, meal_takeaway, restaurant, foo...              4146.0
# 41  [restaurant, food, point_of_interest, establis...                 2.0
# 42  [restaurant, food, point_of_interest, establis...               868.0
# 43  [bar, restaurant, food, point_of_interest, est...             12864.0
# 44  [lodging, restaurant, food, point_of_interest,...               880.0
# 45  [meal_delivery, restaurant, food, point_of_int...              6197.0
# 46  [bar, restaurant, food, point_of_interest, est...              2216.0
# 47  [restaurant, food, point_of_interest, establis...                 4.0
# 48  [cafe, bar, restaurant, food, point_of_interes...              6466.0
# 49  [restaurant, food, point_of_interest, establis...                15.0
# 50  [restaurant, food, point_of_interest, establis...              2297.0
# 51  [restaurant, food, point_of_interest, establis...              8055.0
# 52  [restaurant, bakery, cafe, food, point_of_inte...              1652.0
# 53  [restaurant, food, point_of_interest, establis...              5026.0
# 54  [restaurant, food, point_of_interest, establis...              6768.0
# 55  [restaurant, food, point_of_interest, establis...                70.0
# 56  [restaurant, food, point_of_interest, establis...               745.0
# 57  [bar, restaurant, food, point_of_interest, est...                 7.0
# 58  [restaurant, food, point_of_interest, establis...                11.0
# 59  [restaurant, food, point_of_interest, establis...               219.0
#
#                                              vicinity  price_level
# 0   135, Residency Road, Shanthala Nagar, Ashok Na...          NaN
# 1   UB City, 24, Vittal Mallya Road, Ashok Nagar, ...          NaN
# 2   behind फोर्टिस हॉस्पिटल, 49, Cunningham Cresce...          NaN
# 3   002, Raheja Chancery, 133, Brigade Road, Benga...          NaN
# 4   UB City, Unit No 206, The Collection, No 24, V...          3.0
# 5   50, Lavelle Road, Shanthala Nagar, Ashok Nagar...          3.0
# 6   53, Veeraswamy Garden, K G Nagar, K G Nagar, B...          NaN
# 7   20/2, Vittal Mallya Road, D' Souza Layout, Ash...          3.0
# 8   36, Church Street, Off, Mahatma Gandhi Road, B...          2.0
# 9   near Post Office, Museum Road, Ashok Nagar, Be...          2.0
# 10       40, Saint Marks Road, Ashok Nagar, Bengaluru          3.0
# 11       78, Central Street, Shivaji Nagar, Bengaluru          2.0
# 12  38, Church Street, Sampangi Rama Nagara, Ashok...          2.0
# 13  #72,CHETTALI Trade Center, Next To St.Joseph's...          2.0
# 14  Vidhana Soudha, 3, Raj Bhavan Road, Near, Vasa...          NaN
# 15  45/1, Leo Complex, Residency Cross Road, Benga...          2.0
# 16  near Karnataka Bank, 16, Wood Street, Ashok Na...          3.0
# 17  34, Rest House Road, Shanthala Nagar, Sampangi...          2.0
# 18       3, Raj Bhavan Road, Vasanth Nagar, Bengaluru          NaN
# 19  2nd Floor, UB City, Near-Regent, Vittal Mallya...          2.0
# 20   St. Marks Plaza, 14, Saint Marks Road, Bengaluru          1.0
# 21  Public Utility Building, 2nd, Mahatma Gandhi R...          2.0
# 22  Jayalakshmi Chambers, 57/1, 1st, next to Old G...          2.0
# 23  4/1, O'Shaughnessy Road, Richmond Town, Langfo...          2.0
# 24  43/44, Chandraprabha Complex, Residency Road 1...          1.0
# 25  31, Asha Building, Ground Floor, Church Street...          2.0
# 26  86, Church Street spencer building, Mahatma Ga...          3.0
# 27  No. 2, Brigade Road, St. Patrick's Shopping Ar...          NaN
# 28  41, 42, Residency Road, Shanthala Nagar, Ashok...          2.0
# 29  Tower-B, 13th floor, 84, Mahatma Gandhi Road, ...          3.0
# 30  near Cubbon Park, 23/2 Coffee Day Square, near...          2.0
# 31  Royal Corner 1/5 ground floor double road, opp...          2.0
# 32  Sampangi Rama Nagara, Sampangi Rama Nagar, Ben...          NaN
# 33  next to Bank Of Baroda (E Vijaya), #29/2, Nanj...          2.0
# 34          The Capital,3, Rajbhavan Road,, Bengaluru          NaN
# 35  No 148 & 149, St Thomas Building, Brigade Road...          2.0
# 36      15, Commissariat Road, Ashok Nagar, Bengaluru          2.0
# 37  opp. Citrus Hotel, No. G117/118, Prestige Cent...          3.0
# 38  the Collection, Level 2 UB City, Vittal Mallya...          3.0
# 39   Vivanta Bengaluru, 66, Residency Road, Bengaluru          4.0
# 40  Ground Floor, M G Road Metro Station Reach, 1,...          2.0
# 41          45, Castle Street, Ashok Nagar, Bengaluru          NaN
# 42  opposite to Baldwin Girls High School, Buildin...          2.0
# 43  Allied Grand Plaza, 3rd, 8, Magrath Road, Asho...          3.0
# 44  Near HCG Hospital, 7, Devanga Hostel Road, Sam...          NaN
# 45  opposite Space Centre, Ground Floor & 1st Floo...          2.0
# 46  222, 3rd Floor, "Comet UB City, Vittal Mallya ...          4.0
# 47  Shop Number- 25/4, 1st Floor, ML Subbaraju Roa...          NaN
# 48  39, Saint Marks Road, Shanthala Nagar, Ashok N...          2.0
# 49                                              India          NaN
# 50  2nd floor, Above Mainland China, 33, Church St...          3.0
# 51  opposite Busstand, Near Bowring Hospital Centr...          2.0
# 52  2, 17/1, Cunningham Road Shah Sultan Complex, ...          2.0
# 53           17, Hosur Road, Richmond Town, Bengaluru          2.0
# 54         94, Residency Road, Ashok Nagar, Bengaluru          2.0
# 55  No 48, Triumph Tower, Opp High Gates Hotel, Ch...          NaN
# 56  106/13, Ground Floor, Westminster Building, Cu...          2.0
# 57           Residency Road, Richmond Town, Bengaluru          NaN
# 58                  No. 40/2, Levelle Road, Bengaluru          NaN
# 59  Oakwood Premiere Prestige, Vittal Mallya Road,...          NaN

# %%
# df[['name', 'rating']].plot(kind='bar')

# %%
df.to_csv('restaurants.csv')
